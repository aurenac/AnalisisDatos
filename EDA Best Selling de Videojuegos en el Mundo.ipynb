# %% [markdown]
# <center><img SRC="encabezado.jpg" aling="center"/></center>

# %% [markdown]
# <center><h1 style="color: #4B0082">Análisis Estadístico Descriptivo</h1></center>
# <center><h2 style="color: #9400D3">Best Selling de Videojuegos en el Mundo</h2></center>
# <center><h3 style="color: #FF0000">2020</h3></center>

# %% [markdown]
# <p style="text-aling:justify"> Este es un análisis para poder identificar las características de los videojuegos mayor vendidos a nivel mundial y así poder identificar también cuáles son los más vendidos por categoría y empresa desarrolladora.</p>

# %% [markdown]
# <h2 style="color: #4B0082">1. Carga y estandarización de los archivos de datos</h2>
#
# <h3 style="color: #9400D3">1.1 Importación de librerías</h3>

# %%
# se realiza importación de las librerías necesarias para el EDA
import pandas as pd              #para manejo de DataFrames
import numpy as np               #para manejo de escrituras de datos como listas
import matplotlib as mpl         #para manejo de gráficas
import matplotlib.pyplot as plt  #para manejo de gráficas

# %% [markdown]
# <h3 style="color: #9400D3">1.2 Carga de archivos de datos</h3>

# %%
df = pd.read_csv("dataminer.csv")
df
# Out:
#     Unnamed: 0                                             Title        Sales  \
# 0            0                                         Minecraft  200,000,000
# 1            1                                Grand Theft Auto V  130,000,000
# 2            2                                       Tetris (EA)  100,000,000
# 3            3                                        Wii Sports   82,900,000
# 4            4                     PlayerUnknown's Battlegrounds   60,000,000
# 5            5                                 Super Mario Bros.   48,240,000
# 6            6               Pokémon Red / Green / Blue / Yellow   47,520,000
# 7            7                          Wii Fit and Wii Fit Plus   43,800,000
# 8            8                                 Tetris (Nintendo)   43,000,000
# 9            9                                           Pac-Man   39,098,000
# 10          10                                    Mario Kart Wii   37,320,000
# ...

# %%
df.shape
# Out:
# (51, 7)

# %%
df.head(5)
# Out:
#    Unnamed: 0                          Title        Sales     Platform(s)  \
# 0           0                      Minecraft  200,000,000  Multi-platform
# 1           1             Grand Theft Auto V  130,000,000  Multi-platform
# 2           2                    Tetris (EA)  100,000,000          Mobile
# 3           3                     Wii Sports   82,900,000             Wii
# 4           4  PlayerUnknown's Battlegrounds   60,000,000  Multi-platform
#
#   Initial  release date      Developer(s)      Publisher(s)
# 0  November 18, 2011[b]    Mojang Studios    Mojang Studios
# 1    September 17, 2013    Rockstar North    Rockstar Games
# 2    September 12, 2006         EA Mobile   Electronic Arts
# 3     November 19, 2006      Nintendo EAD          Nintendo
# 4     December 20, 2017  PUBG Corporation  PUBG Corporation

# %%
df.tail(5)
# Out:
#     Unnamed: 0                       Title       Sales      Platform(s)  \
# 46          46        Call of Duty: Ghosts  19,000,000   Multi-platform
# 47          47  Super Smash Bros. Ultimate  18,840,000  Nintendo Switch
# 48          48                Mario Kart 7  18,710,000     Nintendo 3DS
# 49          49            Super Mario Land  18,370,500   Multi-platform
# 50          50              Gran Turismo 4  17,830,000        PS2 / PSP
#
#    Initial  release date                      Developer(s)  \
# 46      November 5, 2013                     Infinity Ward
# 47      December 7, 2018  Bandai Namco Studios / Sora Ltd.
# 48      December 1, 2011                      Nintendo EAD
# 49        April 21, 1989                     Nintendo R&D1
# 50     December 28, 2004                 Polyphony Digital
#
#                    Publisher(s)
# 46                   Activision
# 47                     Nintendo
# 48                     Nintendo
# 49                     Nintendo
# ...

# %% [markdown]
# <h3 style="color: #9400D3">1.3 Revisar encabezados</h3>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 7 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Unnamed: 0             51 non-null     int64
#  1   Title                  51 non-null     object
#  2   Sales                  51 non-null     object
#  3   Platform(s)            51 non-null     object
#  4   Initial  release date  51 non-null     object
#  5   Developer(s)           51 non-null     object
#  6   Publisher(s)           51 non-null     object
# dtypes: int64(1), object(6)
# memory usage: 2.9+ KB

# %%
df.columns = ["Num", "Nombre del videojuego", "Ventas", "Plataformas", "Fecha de lanzamiento", "Desarrollador", "Empresa"]

del(df["Num"])

df = df.replace("Multi-platform", "Multi-plataforma")
df = df.replace("Mobile", "Celular")

df
# Out:
#                                Nombre del videojuego       Ventas  \
# 0                                          Minecraft  200,000,000
# 1                                 Grand Theft Auto V  130,000,000
# 2                                        Tetris (EA)  100,000,000
# 3                                         Wii Sports   82,900,000
# 4                      PlayerUnknown's Battlegrounds   60,000,000
# 5                                  Super Mario Bros.   48,240,000
# 6                Pokémon Red / Green / Blue / Yellow   47,520,000
# 7                           Wii Fit and Wii Fit Plus   43,800,000
# 8                                  Tetris (Nintendo)   43,000,000
# 9                                            Pac-Man   39,098,000
# 10                                    Mario Kart Wii   37,320,000
# 11                             Mario Kart 8 / Deluxe   33,220,000
# 12                                 Wii Sports Resort   33,130,000
# ...

# %% [markdown]
# <h3 style="color: #9400D3">1.4 Generar estadísticas</h3>

# %%
df.describe()
# Out:
#             Nombre del videojuego      Ventas       Plataformas  \
# count                          51          51                51
# unique                         51          44                15
# top     New Super Mario Bros. Wii  20,000,000  Multi-plataforma
# freq                            1           4                27
#
#        Fecha de lanzamiento Desarrollador   Empresa
# count                    51            51        51
# unique                   51            28        17
# top        December 1, 2007  Nintendo EAD  Nintendo
# freq                      1            12        22
